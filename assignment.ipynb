# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Task 1

# %%
# Load the dataset
df = pd.read_csv('messed_dataset.csv')
print(df.head())
# Out:
#                 Name   Age                Email      Country    Salary  \
# 0            invalid  59.0  ycastro@example.org  Switzerland  44694.24
# 1    David Jefferson  21.0                  NaN        China       NaN
# 2      Jessica Reyes  34.0                  NaN          NaN  60511.62
# 3  Kenneth Macdonald  68.0    ewolf@example.com        Italy  84223.29
# 4        Julie Horne  78.0                  NaN      Ecuador  24665.13
#
#   DateOfJoining
# 0    2022-09-29
# 1    2021-10-04
# 2    2022-05-24
# 3    2022-04-07
# 4    2020-06-19

# %%
# viewing and inspecting data
print("The DataFrame:")
df
# Out:
# The DataFrame:
#                   Name   Age                     Email            Country  \
# 0              invalid  59.0       ycastro@example.org        Switzerland
# 1      David Jefferson  21.0                       NaN              China
# 2        Jessica Reyes  34.0                       NaN                NaN
# 3    Kenneth Macdonald  68.0         ewolf@example.com              Italy
# 4          Julie Horne  78.0                       NaN            Ecuador
# ..                 ...   ...                       ...                ...
# 95    Garrett Davidson  56.0        gjames@example.com    Solomon Islands
# 96      Elizabeth Ross  52.0  richardlewis@example.net  Equatorial Guinea
# 97                 NaN  72.0       brian50@example.com            Somalia
# 98      Patricia Singh  65.0      lramirez@example.org             Greece
# 99  Christopher Stokes  42.0                       NaN       South Africa
#
#       Salary DateOfJoining
# 0   44694.24    2022-09-29
# ...

# %%
data_type = df.dtypes
print("DataFrame Data Types:\n\n", data_type)
print("")
print("DataFrame statistics:\n\n", df.describe())
# Out:
# DataFrame Data Types:
#
#  Name             object
# Age              object
# Email            object
# Country          object
# Salary           object
# DateOfJoining    object
# dtype: object
#
# DataFrame statistics:
#
#             Name   Age                Email Country   Salary DateOfJoining
# count        89    97                   80      86       94            79
# unique       85    53                   80      76       93            79
# top     invalid  76.0  ycastro@example.org   China  invalid    2022-09-29
# freq          5     6                    1       2        2             1

# %%
the_shape = df.shape
print("The Data frame is", the_shape[0], "x", the_shape[1])

the_coloumns = list(df.columns)

print("The name of the coloums are:")
for i in range(len(the_coloumns)):
    print(the_coloumns[i])
# Out:
# The Data frame is 100 x 6
# The name of the coloums are:
# Name
# Age
# Email
# Country
# Salary
# DateOfJoining

# %%
print("selecting range of rows from 5 to 8:")
df.loc[5:8]
# Out:
# selecting range of rows from 5 to 8:
#                 Name   Age                     Email      Country    Salary  \
# 5   Jonathan Holland  26.0  mayercaitlin@example.org     Cameroon  25660.99
# 6        James Clark  80.0       ynguyen@example.net          NaN  61345.33
# 7   Kimberly Roberts  76.0       lmiller@example.org  Netherlands  58550.56
# 8  Barbara Armstrong  22.0     fmitchell@example.com          NaN       NaN
#
#   DateOfJoining
# 5    2023-05-01
# 6           NaN
# 7    2023-07-08
# 8           NaN

# %%
print("selecting rows from 1 to 4 and columns from 5 and 6:")
df.iloc[1:5, 4:6]
# Out:
# selecting rows from 1 to 4 and columns from 5 and 6:
#      Salary DateOfJoining
# 1       NaN    2021-10-04
# 2  60511.62    2022-05-24
# 3  84223.29    2022-04-07
# 4  24665.13    2020-06-19

# %% [markdown]
# # Task 2
#
# - Basic Data Cleaning

# %%
df.isnull()
# Out:
#      Name    Age  Email  Country  Salary  DateOfJoining
# 0   False  False  False    False   False          False
# 1   False  False   True    False    True          False
# 2   False  False   True     True   False          False
# 3   False  False  False    False   False          False
# 4   False  False   True    False   False          False
# ..    ...    ...    ...      ...     ...            ...
# 95  False  False  False    False   False           True
# 96  False  False  False    False   False          False
# 97   True  False  False    False   False          False
# 98  False  False  False    False   False          False
# 99  False  False   True    False   False          False
#
# [100 rows x 6 columns]

# %%
df = df[df != "invalid"]
df =  df.dropna()
df
# Out:
#                       Name   Age                        Email  \
# 3        Kenneth Macdonald  68.0            ewolf@example.com
# 5         Jonathan Holland  26.0     mayercaitlin@example.org
# 7         Kimberly Roberts  76.0          lmiller@example.org
# 9              Jason Perez  59.0    collinsedward@example.com
# 10           Olivia Strong  76.0  schultzpatricia@example.com
# 13          Jessica Rivera  73.0        fmitchell@example.net
# 20           Dylan Simpson  46.0        jessica74@example.net
# 23              Karen Ward  56.0         daniel47@example.com
# 24              Amy Henson  80.0       tylerwatts@example.org
# 28           Ricardo Moody  76.0         xmorales@example.net
# 29          Stephanie Moss  61.0         qvaughan@example.com
# 35           Rebecca Davis  35.0  wallacejennifer@example.net
# 36         Keith Velazquez  22.0        charles82@example.net
# 37      Christopher Martin  40.0           tina11@example.com
# ...

# %%
df = df.assign(Address=[""]*43)
df
# Out:
#                       Name   Age                        Email  \
# 3        Kenneth Macdonald  68.0            ewolf@example.com
# 5         Jonathan Holland  26.0     mayercaitlin@example.org
# 7         Kimberly Roberts  76.0          lmiller@example.org
# 9              Jason Perez  59.0    collinsedward@example.com
# 10           Olivia Strong  76.0  schultzpatricia@example.com
# 13          Jessica Rivera  73.0        fmitchell@example.net
# 20           Dylan Simpson  46.0        jessica74@example.net
# 23              Karen Ward  56.0         daniel47@example.com
# 24              Amy Henson  80.0       tylerwatts@example.org
# 28           Ricardo Moody  76.0         xmorales@example.net
# 29          Stephanie Moss  61.0         qvaughan@example.com
# 35           Rebecca Davis  35.0  wallacejennifer@example.net
# 36         Keith Velazquez  22.0        charles82@example.net
# 37      Christopher Martin  40.0           tina11@example.com
# ...

# %%
del df['Address']
df
# Out:
#                       Name   Age                        Email  \
# 3        Kenneth Macdonald  68.0            ewolf@example.com
# 5         Jonathan Holland  26.0     mayercaitlin@example.org
# 7         Kimberly Roberts  76.0          lmiller@example.org
# 9              Jason Perez  59.0    collinsedward@example.com
# 10           Olivia Strong  76.0  schultzpatricia@example.com
# 13          Jessica Rivera  73.0        fmitchell@example.net
# 20           Dylan Simpson  46.0        jessica74@example.net
# 23              Karen Ward  56.0         daniel47@example.com
# 24              Amy Henson  80.0       tylerwatts@example.org
# 28           Ricardo Moody  76.0         xmorales@example.net
# 29          Stephanie Moss  61.0         qvaughan@example.com
# 35           Rebecca Davis  35.0  wallacejennifer@example.net
# 36         Keith Velazquez  22.0        charles82@example.net
# 37      Christopher Martin  40.0           tina11@example.com
# ...

# %%
df.columns = ['Name', 'Age', 'Email Address', 'Country', 'Salary', 'Date Joined']
df
# Out:
#                       Name   Age                Email Address  \
# 3        Kenneth Macdonald  68.0            ewolf@example.com
# 5         Jonathan Holland  26.0     mayercaitlin@example.org
# 7         Kimberly Roberts  76.0          lmiller@example.org
# 9              Jason Perez  59.0    collinsedward@example.com
# 10           Olivia Strong  76.0  schultzpatricia@example.com
# 13          Jessica Rivera  73.0        fmitchell@example.net
# 20           Dylan Simpson  46.0        jessica74@example.net
# 23              Karen Ward  56.0         daniel47@example.com
# 24              Amy Henson  80.0       tylerwatts@example.org
# 28           Ricardo Moody  76.0         xmorales@example.net
# 29          Stephanie Moss  61.0         qvaughan@example.com
# 35           Rebecca Davis  35.0  wallacejennifer@example.net
# 36         Keith Velazquez  22.0        charles82@example.net
# 37      Christopher Martin  40.0           tina11@example.com
# ...

# %%
def salary_increase(salary):
    increased = str((float(salary)*2))
    return increased

df['Salary'] = df['Salary'].apply(salary_increase)
df
# Out:
#                       Name   Age                Email Address  \
# 3        Kenneth Macdonald  68.0            ewolf@example.com
# 5         Jonathan Holland  26.0     mayercaitlin@example.org
# 7         Kimberly Roberts  76.0          lmiller@example.org
# 9              Jason Perez  59.0    collinsedward@example.com
# 10           Olivia Strong  76.0  schultzpatricia@example.com
# 13          Jessica Rivera  73.0        fmitchell@example.net
# 20           Dylan Simpson  46.0        jessica74@example.net
# 23              Karen Ward  56.0         daniel47@example.com
# 24              Amy Henson  80.0       tylerwatts@example.org
# 28           Ricardo Moody  76.0         xmorales@example.net
# 29          Stephanie Moss  61.0         qvaughan@example.com
# 35           Rebecca Davis  35.0  wallacejennifer@example.net
# 36         Keith Velazquez  22.0        charles82@example.net
# 37      Christopher Martin  40.0           tina11@example.com
# ...

# %% [markdown]
# # Task 3
# - Data Analysis. Analyse the data by giving the summary statistics, and more information about the data

# %%
group_data = (df.groupby('Country'))

group_data.first()
# Out:
#                                               Name   Age  \
# Country
# Armenia                             Mitchell Smith  32.0
# Bahamas                             Ryan Middleton  42.0
# Bahrain                              Ricardo Moody  76.0
# Bosnia and Herzegovina                  Amy Henson  80.0
# Burkina Faso                       Keith Velazquez  22.0
# Cameroon                          Jonathan Holland  26.0
# Cape Verde                            Morgan Brown  79.0
# Central African Republic            Jessica Rivera  73.0
# Colombia                             Andrew Bryant  43.0
# Congo                                   Karen Ward  56.0
# Czech Republic                         Nancy Irwin  42.0
# Ecuador                                Brandi Long  45.0
# Equatorial Guinea                   Elizabeth Ross  52.0
# Greece                           Patrick Brown PhD  44.0
# Grenada                           Michael Oconnell  19.0
# ...

# %%
group_data.size().reset_index(name='counts')
# Out:
#                        Country  counts
# 0                      Armenia       1
# 1                      Bahamas       1
# 2                      Bahrain       1
# 3       Bosnia and Herzegovina       1
# 4                 Burkina Faso       1
# 5                     Cameroon       1
# 6                   Cape Verde       1
# 7     Central African Republic       1
# 8                     Colombia       1
# 9                        Congo       1
# 10              Czech Republic       1
# 11                     Ecuador       1
# 12           Equatorial Guinea       1
# 13                      Greece       2
# 14                     Grenada       1
# 15                    Guernsey       1
# 16               Guinea-Bissau       1
# 17                     Iceland       1
# 18                       Italy       1
# 19                  Luxembourg       1
# 20                      Malawi       1
# 21                  Mauritania       1
# 22                     Moldova       1
# ...

# %%
data_second = df.copy()
df['Datetime'] = pd.to_datetime(df['Date Joined'])
df = df.set_index('Datetime')
df = df.drop("Date Joined", axis=1)
df
# Out:
#                               Name   Age                Email Address  \
# Datetime
# 2022-04-07       Kenneth Macdonald  68.0            ewolf@example.com
# 2023-05-01        Jonathan Holland  26.0     mayercaitlin@example.org
# 2023-07-08        Kimberly Roberts  76.0          lmiller@example.org
# 2024-04-11             Jason Perez  59.0    collinsedward@example.com
# 2023-07-27           Olivia Strong  76.0  schultzpatricia@example.com
# 2021-05-18          Jessica Rivera  73.0        fmitchell@example.net
# 2021-10-31           Dylan Simpson  46.0        jessica74@example.net
# 2022-04-09              Karen Ward  56.0         daniel47@example.com
# 2023-12-11              Amy Henson  80.0       tylerwatts@example.org
# 2024-03-29           Ricardo Moody  76.0         xmorales@example.net
# 2021-11-22          Stephanie Moss  61.0         qvaughan@example.com
# 2022-08-06           Rebecca Davis  35.0  wallacejennifer@example.net
# ...

# %%
excel_data = pd.read_excel("SaleData.xlsx")
excel_data.head()
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television   95.0      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0       500.0
# 2 2018-02-09  Central  Hermann       Luis    Television   36.0      1198.0
# 3 2018-02-26  Central  Timothy      David    Cell Phone   27.0       225.0
# 4 2018-03-15     West  Timothy    Stephen    Television   56.0      1198.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0
# 2   43128.0
# 3    6075.0
# 4   67088.0

# %% [markdown]
# # Data Visualization
# - Visualize the data by using the visualization libraries

# %%
data_second = data_second.loc[0:20]
data_second = data_second.sort_values(['Age', 'Salary'], ascending=False)
plt.plot(data_second['Salary'], data_second['Age'])
plt.xlabel('Salary')
plt.ylabel('Age')
plt.title('Salary v Age')
plt.show()
# Out:
# balls

# %%
sns.barplot(x = 'Salary',
            y = 'Age',
            data = data_second)
plt.show()
